# %% [markdown]
# # Extract csv file data

# %%
import pandas as pd
data=pd.read_excel('district_wise.xls',index_col="State_Code")
rows=data.loc["DL"]
#print(type[rows])
rows
# Out:
#             SlNo  State         District_Key          District  Confirmed  \
# State_Code
# DL           144  Delhi     DL_Central Delhi     Central Delhi        184
# DL           145  Delhi        DL_East Delhi        East Delhi         38
# DL           146  Delhi         DL_New Delhi         New Delhi         37
# DL           147  Delhi       DL_North Delhi       North Delhi         60
# DL           148  Delhi  DL_North East Delhi  North East Delhi         25
# DL           149  Delhi  DL_North West Delhi  North West Delhi         32
# DL           150  Delhi          DL_Shahdara          Shahdara         48
# DL           151  Delhi       DL_South Delhi       South Delhi         70
# DL           152  Delhi  DL_South East Delhi  South East Delhi        130
# DL           153  Delhi  DL_South West Delhi  South West Delhi         42
# DL           154  Delhi        DL_West Delhi        West Delhi        122
# ...

# %%
EXTRACT EXCEL DATA

# %%
import pandas as pd
data=pd.read_csv('district_wise.csv',index_col="State_Code")
rows=data.loc["DL"]
#print(type[rows])
rows
# Out:
#             SlNo  State         District_Key          District  Confirmed  \
# State_Code
# DL           144  Delhi     DL_Central Delhi     Central Delhi        184
# DL           145  Delhi        DL_East Delhi        East Delhi         38
# DL           146  Delhi         DL_New Delhi         New Delhi         37
# DL           147  Delhi       DL_North Delhi       North Delhi         60
# DL           148  Delhi  DL_North East Delhi  North East Delhi         25
# DL           149  Delhi  DL_North West Delhi  North West Delhi         32
# DL           150  Delhi          DL_Shahdara          Shahdara         48
# DL           151  Delhi       DL_South Delhi       South Delhi         70
# DL           152  Delhi  DL_South East Delhi  South East Delhi        130
# DL           153  Delhi  DL_South West Delhi  South West Delhi         42
# DL           154  Delhi        DL_West Delhi        West Delhi        122
# ...
