# %%
import matplotlib.pyplot as plt
import pandas as pd
df =  pd.read_csv('covid_19_india.csv')
cured_data = df["Cured"]
deaths_data = df["Deaths"]
confirmed_data=df["Confirmed"]
date_data=df["Date"]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#8c564b"]
explode = (0.1, 0, 0, 0, 0)  
plt.pie(cured_data, labels=confirmed_data, explode=explode, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Gold medal achievements of five most successful\n"+"countries in 2016 Summer Olympics")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-9ff80a116f1b> in <module>
#       9 explode = (0.1, 0, 0, 0, 0)
#      10 plt.pie(cured_data, labels=confirmed_data, explode=explode, colors=colors,
# ---> 11 autopct='%1.1f%%', shadow=True, startangle=140)
#      12 plt.title("Gold medal achievements of five most successful\n"+"countries in 2016 Summer Olympics")
#      13 plt.show()
#
# C:\Users\ELCOT\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2786         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2787         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2788         data is not None else {}))
#    2789
#    2790
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
ax=plt.gca
data=  pd.read_csv('covid_19_india.csv',index_col="State/UnionTerritory")
#data=pd.read_csv('district_wise.csv',index_col="State_Code")
df=data.loc["Delhi"]
#print(type[rows])
df
#cured_data = df["Cured"]
#deaths_data = df["Deaths"]
#confirmed_data=df["Confirmed"]
#date_data=df["Date"]
df.plot(kind='line', x='Date', y='Cured',ax=ax)
df.plot(kind='line', x='Date', y='Deaths',color='red',ax=ax)
df.plot(kind='line', x='Date', y='Confirmed',color='green',ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-a8306bca31a2> in <module>
#      11 #confirmed_data=df["Confirmed"]
#      12 #date_data=df["Date"]
# ---> 13 df.plot(kind='line', x='Date', y='Cured',ax=ax)
#      14 df.plot(kind='line', x='Date', y='Deaths',color='red',ax=ax)
#      15 df.plot(kind='line', x='Date', y='Confirmed',color='green',ax=ax)
#
# C:\Users\ELCOT\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# C:\Users\ELCOT\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
data=pd.read_csv('covid_19_india.csv',index_col="State/UnionTerritory")
#data=pd.read_csv('district_wise.csv',index_col="State_Code")
df=data.loc["Tamil Nadu"]
#print(type[rows])
df
df.plot(x="Date",y=["Cured","Confirmed","Deaths"])
plt.show()
